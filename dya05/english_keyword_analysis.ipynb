# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (3.5.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.34.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (1.8.2.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (1.23.0)
# Requirement already satisfied: pillow in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.4.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#자연어처리
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from nltk) (2022.7.25)
# Requirement already satisfied: click in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: tqdm in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from nltk) (4.64.0)
# Requirement already satisfied: joblib in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from click->nltk) (0.4.5)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import glob
import re
from functools import reduce
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import  Counter
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS, WordCloud
#구글 mapreduce 크롤링 공부 하는 것을 추천

# %%
#### NLTK 리소스를 최초 한번 다운로드

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
#파일병합
all_files = glob.glob('./data/myCabinetExcelData*.xls')
all_files
# Out:
# ['./data\\myCabinetExcelData (1).xls',
#  './data\\myCabinetExcelData (2).xls',
#  './data\\myCabinetExcelData (3).xls',
#  './data\\myCabinetExcelData (4).xls',
#  './data\\myCabinetExcelData.xls']

# %%
all_data = []
for file in all_files:
    df = pd.read_excel(file)
    all_data.append(df)

all_data[0]
# Out:
#     Unnamed: 0   번호                                                 제목  \
# 0          NaN    1  Call for Special Issue Papers: Big Data Analyt...
# 1          NaN    2  Call for Papers: Special Issue on Big Data in ...
# 2          NaN    3  An Exercise in Exploring Big Data for Producin...
# 3          NaN    4  Big Data in Healthcare: Opportunities and Chal...
# 4          NaN    5  Internet of Things-Based Optimized Routing and...
# ..         ...  ...                                                ...
# 95         NaN   96  Availability modelling and assurance for a big...
# 96         NaN   97  Big Earth Data: a comprehensive analysis of vi...
# 97         NaN   98  Big Earth data: A new frontier in Earth and in...
# 98         NaN   99  GSio: A programmatic interface for delivering ...
# 99         NaN  100  A view-based model of data-cube to support big...
#
#                                                    저자                    출판사  \
# 0   El-Latif, Ahmed A. Abd; Tawalbeh, Lo'ai; Maleh...       Mary Ann Leibert
# 1                                             unknown       Mary Ann Leibert
# 2                                             unknown       Mary Ann Leibert
# 3                                             unknown       Mary Ann Leibert
# 4   Menon, Varun G.; Verma, Sandeep; Kaur, Satnam;...       Mary Ann Leibert
# ..                                                ...                    ...
# 95                         Ke, Zuqiang; Park, Nohpill           Inderscience
# 96  Merritt, Patrick; Bi, Haixia; Davis, Bradley; ...  John Wiley & Sons Ltd
# 97                                       Guo, Huadong  John Wiley & Sons Ltd
# 98  Larraondo, Pablo R.; Pringle, Sean; Guo, Jian;...  John Wiley & Sons Ltd
# 99     Nativi, Stefano; Mazzetti, Paolo; Craglia, Max  John Wiley & Sons Ltd
#
#      출판일
# 0   2021
# 1   2016
# 2   2016
# 3   2015
# 4   2021
# ..   ...
# 95  2019
# 96  2018
# 97  2017
# 98  2017
# 99  2017
#
# [100 rows x 6 columns]

# %%
all_data_concat = pd.concat(all_data, axis=0, ignore_index=True)
all_data_concat
# Out:
#      Unnamed: 0   번호                                                 제목  \
# 0           NaN    1  Call for Special Issue Papers: Big Data Analyt...
# 1           NaN    2  Call for Papers: Special Issue on Big Data in ...
# 2           NaN    3  An Exercise in Exploring Big Data for Producin...
# 3           NaN    4  Big Data in Healthcare: Opportunities and Chal...
# 4           NaN    5  Internet of Things-Based Optimized Routing and...
# ..          ...  ...                                                ...
# 495         NaN   96  Comparative study of big data of global adakit...
# 496         NaN   97  Furthest-Pair-Based Binary Search Tree for Spe...
# 497         NaN   98  New discrimination diagrams for basalts based ...
# 498         NaN   99               Big Data 2.0: Cataclysm or Catalyst?
# 499         NaN  100                               Big Data on Robotics
#
#                                                     저자                    출판사  \
# 0    El-Latif, Ahmed A. Abd; Tawalbeh, Lo'ai; Maleh...       Mary Ann Leibert
# 1                                              unknown       Mary Ann Leibert
# 2                                              unknown       Mary Ann Leibert
# 3                                              unknown       Mary Ann Leibert
# 4    Menon, Varun G.; Verma, Sandeep; Kaur, Satnam;...       Mary Ann Leibert
# ..                                                 ...                    ...
# 495  Xuelong, Liu; Wenchang, Li; Qi, Zhang; Na, Zha...  John Wiley & Sons Ltd
# 496                                 Hassanat, A. B. A.       Mary Ann Leibert
# 497  Zhang, Qi; Sun, Weidong; Zhao, Yong; Yuan, Fan...  John Wiley & Sons Ltd
# 498                                            unknown       Mary Ann Leibert
# 499                                            unknown       Mary Ann Leibert
#
#       출판일
# 0    2021
# 1    2016
# 2    2016
# 3    2015
# 4    2021
# ..    ...
# 495  2018
# 496  2018
# 497  2019
# 498  2014
# 499  2016
#
# [500 rows x 6 columns]

# %%
all_data_concat = all_data_concat.drop(all_data_concat.columns[[0]],axis='columns')
all_data_concat
# Out:
#       번호                                                 제목  \
# 0      1  Call for Special Issue Papers: Big Data Analyt...
# 1      2  Call for Papers: Special Issue on Big Data in ...
# 2      3  An Exercise in Exploring Big Data for Producin...
# 3      4  Big Data in Healthcare: Opportunities and Chal...
# 4      5  Internet of Things-Based Optimized Routing and...
# ..   ...                                                ...
# 495   96  Comparative study of big data of global adakit...
# 496   97  Furthest-Pair-Based Binary Search Tree for Spe...
# 497   98  New discrimination diagrams for basalts based ...
# 498   99               Big Data 2.0: Cataclysm or Catalyst?
# 499  100                               Big Data on Robotics
#
#                                                     저자                    출판사  \
# 0    El-Latif, Ahmed A. Abd; Tawalbeh, Lo'ai; Maleh...       Mary Ann Leibert
# 1                                              unknown       Mary Ann Leibert
# 2                                              unknown       Mary Ann Leibert
# 3                                              unknown       Mary Ann Leibert
# 4    Menon, Varun G.; Verma, Sandeep; Kaur, Satnam;...       Mary Ann Leibert
# ..                                                 ...                    ...
# 495  Xuelong, Liu; Wenchang, Li; Qi, Zhang; Na, Zha...  John Wiley & Sons Ltd
# 496                                 Hassanat, A. B. A.       Mary Ann Leibert
# 497  Zhang, Qi; Sun, Weidong; Zhao, Yong; Yuan, Fan...  John Wiley & Sons Ltd
# 498                                            unknown       Mary Ann Leibert
# 499                                            unknown       Mary Ann Leibert
#
#       출판일
# 0    2021
# 1    2016
# 2    2016
# 3    2015
# 4    2021
# ..    ...
# 495  2018
# 496  2018
# 497  2019
# 498  2014
# 499  2016
#
# [500 rows x 5 columns]

# %%
all_data_concat.to_csv('./data/riss_bigdata.csv', index=False, encoding='utf-8')

# %% [markdown]
# #### 데이터전처리

# %%
all_title = all_data_concat['제목']
all_title
# Out:
# 0      Call for Special Issue Papers: Big Data Analyt...
# 1      Call for Papers: Special Issue on Big Data in ...
# 2      An Exercise in Exploring Big Data for Producin...
# 3      Big Data in Healthcare: Opportunities and Chal...
# 4      Internet of Things-Based Optimized Routing and...
#                              ...
# 495    Comparative study of big data of global adakit...
# 496    Furthest-Pair-Based Binary Search Tree for Spe...
# 497    New discrimination diagrams for basalts based ...
# 498                 Big Data 2.0: Cataclysm or Catalyst?
# 499                                 Big Data on Robotics
# Name: 제목, Length: 500, dtype: object

# %%
#여러가지 부사나 동사 등 불필요한 것을 제거
stopWords = set(stopwords.words('english'))
stopWords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
lemma = WordNetLemmatizer()

# %%
words = []
#명사(keyword)만 남기기
for title in all_title:
    EnWords  = re.sub(r'[^a-zA-Z]+',' ',str(title))
    EnWordsToken = word_tokenize(EnWords.lower())
    EnWordsTokenStop = [w for w in EnWordsToken if w not in stopWords]
    EnWordsTokenStopLemma = [lemma.lemmatize(w) for w in EnWordsTokenStop]

    words.append(EnWordsTokenStopLemma)

# %%
print(words) # 결과 값이 2차원리스트 형태 ex) list = [[]]
# Out:
# [['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity'], ['call', 'paper', 'special', 'issue', 'big', 'data', 'robotics'], ['exercise', 'exploring', 'big', 'data', 'producing', 'reliable', 'statistical', 'information'], ['big', 'data', 'healthcare', 'opportunity', 'challenge'], ['internet', 'thing', 'based', 'optimized', 'routing', 'big', 'data', 'gathering', 'system', 'landslide', 'detection'], ['call', 'special', 'issue', 'paper', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering'], ['ensemble', 'based', 'scalable', 'approach', 'intrusion', 'detection', 'using', 'big', 'data', 'framework'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'industrial', 'intelligence'], ['call', 'paper', 'special', 'issue', 'computational', 'propaganda', 'political', 'big', 'data'], ['research', 'dilemma', 'behavioral', 'big', 'data'], ['call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot'], ['big', 'data', 'support', 'sustainable', 'development', 'goal', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas'], ['correction', 'big', 'data'], ['call', 'special', 'issue', 'paper', 'deep', 'learning', 'assisted', 'big', 'data', 'analytics', 'biomedical', 'application', 'digital', 'healthcare'], ['call', 'special', 'issue', 'paper', 'deep', 'learning', 'assisted', 'big', 'data', 'analytics', 'biomedical', 'application', 'digital', 'healthcare'], ['call', 'paper', 'special', 'issue', 'computational', 'propaganda', 'political', 'big', 'data'], ['remotely', 'sensed', 'big', 'data', 'ocean', 'polar', 'region'], ['u', 'army', 'person', 'event', 'data', 'environment', 'military', 'civilian', 'big', 'data', 'enterprise'], ['atmospheric', 'ecosystem', 'big', 'data', 'providing', 'key', 'contribution', 'reaching', 'united', 'nation', 'sustainable', 'development', 'goal'], ['earth', 'observation', 'geospatial', 'big', 'data', 'management', 'engagement', 'stakeholder', 'hungary', 'support', 'sdgs'], ['combining', 'human', 'computing', 'machine', 'learning', 'make', 'sense', 'big', 'aerial', 'data', 'disaster', 'response'], ['call', 'paper', 'special', 'issue', 'big', 'data', 'robotics'], ['big', 'data', 'support', 'sustainable', 'development', 'goal', 'continued', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas'], ['exploiting', 'reused', 'based', 'sharing', 'work', 'opportunity', 'big', 'data', 'multiquery', 'optimization', 'flink'], ['unsupervised', 'tensor', 'mining', 'big', 'data', 'practitioner'], ['call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot'], ['call', 'special', 'issue', 'paper', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering'], ['big', 'data', 'analytics', 'capability', 'digital', 'transformation', 'insurance', 'sector'], ['big', 'data', 'little', 'data', 'care', 'coordination', 'medicare', 'beneficiary', 'medigap', 'coverage'], ['medical', 'school', 'training', 'relate', 'practice', 'evidence', 'big', 'data'], ['big', 'data', 'social', 'good'], ['national', 'survey', 'population', 'health', 'big', 'data', 'analytics', 'mobile', 'health', 'monitor'], ['big', 'data', 'enabler', 'primary', 'education'], ['agile', 'big', 'data', 'analytics', 'web', 'based', 'system', 'architecture', 'centric', 'approach'], ['intelligent', 'big', 'data', 'analysis', 'review'], ['leveraging', 'big', 'data', 'analytics', 'case', 'kenyan', 'telecom'], ['big', 'data', 'analytics', 'framework', 'border', 'crossing', 'transportation'], ['scalable', 'big', 'data', 'modelling'], ['clustering', 'big', 'spatiotemporal', 'interval', 'data'], ['intelligent', 'big', 'data', 'analysis', 'review'], ['analyzing', 'big', 'smart', 'metering', 'data', 'towards', 'differentiated', 'user', 'service', 'sublinear', 'approach'], [ ...

# %%
words_reduce = list(reduce(lambda x, y: x+y, words))#차원축소 2차원 -> 1차원
print(words_reduce)
# Out:
# ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity', 'call', 'paper', 'special', 'issue', 'big', 'data', 'robotics', 'exercise', 'exploring', 'big', 'data', 'producing', 'reliable', 'statistical', 'information', 'big', 'data', 'healthcare', 'opportunity', 'challenge', 'internet', 'thing', 'based', 'optimized', 'routing', 'big', 'data', 'gathering', 'system', 'landslide', 'detection', 'call', 'special', 'issue', 'paper', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering', 'ensemble', 'based', 'scalable', 'approach', 'intrusion', 'detection', 'using', 'big', 'data', 'framework', 'call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'industrial', 'intelligence', 'call', 'paper', 'special', 'issue', 'computational', 'propaganda', 'political', 'big', 'data', 'research', 'dilemma', 'behavioral', 'big', 'data', 'call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot', 'big', 'data', 'support', 'sustainable', 'development', 'goal', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas', 'correction', 'big', 'data', 'call', 'special', 'issue', 'paper', 'deep', 'learning', 'assisted', 'big', 'data', 'analytics', 'biomedical', 'application', 'digital', 'healthcare', 'call', 'special', 'issue', 'paper', 'deep', 'learning', 'assisted', 'big', 'data', 'analytics', 'biomedical', 'application', 'digital', 'healthcare', 'call', 'paper', 'special', 'issue', 'computational', 'propaganda', 'political', 'big', 'data', 'remotely', 'sensed', 'big', 'data', 'ocean', 'polar', 'region', 'u', 'army', 'person', 'event', 'data', 'environment', 'military', 'civilian', 'big', 'data', 'enterprise', 'atmospheric', 'ecosystem', 'big', 'data', 'providing', 'key', 'contribution', 'reaching', 'united', 'nation', 'sustainable', 'development', 'goal', 'earth', 'observation', 'geospatial', 'big', 'data', 'management', 'engagement', 'stakeholder', 'hungary', 'support', 'sdgs', 'combining', 'human', 'computing', 'machine', 'learning', 'make', 'sense', 'big', 'aerial', 'data', 'disaster', 'response', 'call', 'paper', 'special', 'issue', 'big', 'data', 'robotics', 'big', 'data', 'support', 'sustainable', 'development', 'goal', 'continued', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas', 'exploiting', 'reused', 'based', 'sharing', 'work', 'opportunity', 'big', 'data', 'multiquery', 'optimization', 'flink', 'unsupervised', 'tensor', 'mining', 'big', 'data', 'practitioner', 'call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot', 'call', 'special', 'issue', 'paper', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering', 'big', 'data', 'analytics', 'capability', 'digital', 'transformation', 'insurance', 'sector', 'big', 'data', 'little', 'data', 'care', 'coordination', 'medicare', 'beneficiary', 'medigap', 'coverage', 'medical', 'school', 'training', 'relate', 'practice', 'evidence', 'big', 'data', 'big', 'data', 'social', 'good', 'national', 'survey', 'population', 'health', 'big', 'data', 'analytics', 'mobile', 'health', 'monitor', 'big', 'data', 'enabler', 'primary', 'education', 'agile', 'big', 'data', 'analytics', 'web', 'based', 'system', 'architecture', 'centric', 'approach', 'intelligent', 'big', 'data', 'analysis', 'review', 'leveraging', 'big', 'data', 'analytics', 'case', 'kenyan', 'telecom', 'big', 'data', 'analytics', 'framework', 'border', 'crossing', 'transportation', 'scalable', 'big', 'data', 'modelling', 'clustering', 'big', 'spatiotemporal', 'interval', 'data', 'intelligent', 'big', 'data', 'analysis', 'review', 'analyzing', 'big', 'smart', 'metering', 'data', 'towards', 'differentiated', 'user', 'service', 'sublinear', 'approach', 'improved', 'big', 'data', 'stock', 'index', 'prediction', 'using', 'deep', 'learni ...

# %%
count = Counter(words_reduce) #count클래스 각각의 갯수를 표시

count
# Out:
# Counter({'call': 30,
#          'special': 31,
#          'issue': 35,
#          'paper': 28,
#          'big': 528,
#          'data': 576,
#          'analytics': 89,
#          'intelligent': 10,
#          'system': 33,
#          'cybersecurity': 1,
#          'robotics': 3,
#          'exercise': 1,
#          'exploring': 4,
#          'producing': 1,
#          'reliable': 1,
#          'statistical': 4,
#          'information': 6,
#          'healthcare': 8,
#          'opportunity': 7,
#          'challenge': 13,
#          'internet': 11,
#          'thing': 9,
#          'based': 46,
#          'optimized': 2,
#          'routing': 1,
#          'gathering': 1,
#          'landslide': 1,
#          'detection': 8,
#          'scientific': 7,
#          'machine': 19,
#          'learning': 30,
#          'science': 18,
#          'engineering': 12,
#          'ensemble': 3,
#          'scalable': 17,
#          'approach': 39,
#          'intrusion': 1,
#          'using': 30,
#          'framework': 28,
#          'industrial': 2,
#          'intelligence': 11,
#          'computational': 6,
#          'propaganda': 3,
#          'political': 3,
#          'research': 14,
#          'dilemma': 1,
#          'behavioral': 3,
#          'cloud': 22,
#          'computing': 14,
#          'cognitive': 2,
#          'iot': 4,
#          'support': 10,
#          'sustainable': 15,
#          'development': 12,
#          'goal': 9,
#          'celebration': 2,
#          'establishment': 2,
#          'international': 3,
#          'center': 5,
#          'cbas': 2,
#          'correction': 4,
#          'deep': 9,
#          'assisted': 3,
#          'biomedical': 3,
#          'application': 20,
#          'digital': 6,
#          'remotely': 1,
#          'sensed': 1,
#          'ocean': 1,
#          'polar': 1,
#          'region': 2,
#          'u': 1,
#          'army': 1,
#          'person': 1,
#          'event': 1,
#          'environment': 7,
#          'military': 1,
#          'civilian': 1,
#          'enterprise': 7,
#          'atmospheric': 1,
#          'ecosystem': 3,
#          'providing': 1,
#          'key': 1,
#          'contribution': 1,
#          'reaching': 1,
#          'united': 1,
#          'nation': 1,
#          'earth': 22,
#          'observation': 3,
#          'geospatial': 3,
#          'management': 18,
#          'engagement': 1,
#          'stakeholder': 2,
#          'hungary': 1,
#          'sdgs': 1,
#          'combining': 1,
#          'human': 6,
#          'make': 3,
#          'sense': 1,
#          'aerial': 3,
#          'disaster': 6,
#          'response': 2,
#          'continued': 2,
#          'exploiting': 2,
#          'reused': 1,
#          'sharing': 5,
#          'work': 1,
#          'multiquery': 1,
#          'optimization': 7,
#          'flink': 2,
#          'unsupervised': 1,
#          'tensor': 4,
#          'mining': 17,
#          'practitioner': 1,
#          'capability': 3,
#          'transformation': 6,
#          'insurance': 1,
#          'sector': 5,
#          'little': 1,
#          'care': 4,
#          'coordination': 1,
#          'medicare': 1,
#          'beneficiary': 1,
#          'medigap': 1,
#          'coverage': 1,
#          'medical': 4,
#          'school': 1,
#          'training': 2,
#          'relate': 1,
#          'practice': 2,
#          'evidence': 6,
#          'social': 7,
#          'good': 1,
#          'national': 5,
#          'survey': 14,
#          'population': 1,
#          'health': 12,
#          'mobile': 1,
#          'monitor': 1,
#          'enabler': 1,
#          'primary': 1,
#          'education': 6,
#          'agile': 1,
#          'web': 7,
#          'architecture': 6,
#          'centric': 1,
#          'analysis': 40,
#          'review': 16,
#          'leveraging': 2,
#          'case': 3,
#          'kenyan': 1,
#          'telecom': 2,
#          'border': 1,
#          'crossing': 1,
#          'transportation': 5,
#          'modelling': 2,
#          'clustering': 9,
#          'spatiotemporal': 1,
#          'interval': 3,
#          'analyzing': 5,
#          'smart': 11,
#          'metering': 1,
#          'towards': 9,
#          'differentiated': 1,
#          'user': 1,
#          'service': 11,
#          'sublinear': 1,
#          'improved': 1,
#          'stock': 4,
#          'index': 4,
#          'prediction': 10,
#          'cnn': 1,
#          'gru': 1,
#          'current': 3,
#          'perspective': 18,
#          'potential': 4,
#          'solution': 4,
#          'guest': 9,
#          'editorial': 11,
#          'scholar': 3,
#          'discovery': 5,
#          'collaboration': 4,
#          'infrastructure': 10,
#          'speed': 1,
#          'unveiling': 1,
#          'storage': 6,
#          'distribution': 6,
#          'sub': 1,
#          'datasets': 3,
#          'platform': 16,
#          'distributed': 20,
#          'scale': 7,
#          'deduplication': 3,
#          'encrypted': 1,
#          'eeg': 1,
#          'seizure': 1,
#          'bci': 1,
#          'via': 6,
#          'hierarchical': 1,
#          'processing': 19,
#          'image': 2,
#          'feature': 4,
#          'selection': 5,
#          'efficient': 18,
#          'economic': 1,
#          'structural': 2,
#          'balance': 1,
#          'theory': 4,
#          'e': 2,
#          'commerce': 1,
#          'recommendation': 1,
#          'rating': 3,
#          'hdm': 1,
#          'composable': 1,
#          'quality': 6,
#          'driven': 17,
#          'consistency': 2,
#          'taxi': 1,
#          'passenger': 1,
#          'demand': 3,
#          'modeling': 10,
#          'roving': 1,
#          'sensor': 7,
#          'network': 10,
#          'five': 2,
#          'layer': 1,
#          'thermal': 1,
#          'aware': 3,
#          'dvfs': 1,
#          'enabled': 3,
#          'task': 2,
#          'scheduling': 5,
#          'trend': 3,
#          'predictive': 4,
#          'perception': 3,
#          'independent': 1,
#          'financial': 4,
#          'advisor': 1,
#          'usefulness': 1,
#          'context': 4,
#          'decision': 5,
#          'making': 7,
#          'uk': 1,
#          'hybridisation': 1,
#          'classifier': 3,
#          'anomaly': 1,
#          'max': 1,
#          'min': 1,
#          'fair': 1,
#          'resource': 3,
#          'allocation': 3,
#          'stream': 3,
#          'shared': 1,
#          'online': 13,
#          'similarity': 3,
#          'overfitting': 1,
#          'kvasir': 1,
#          'provision': 1,
#          'semantically': 3,
#          'relevant': 2,
#          'content': 6,
#          'concentric': 1,
#          'business': 9,
#          'value': 3,
#          'parallel': 4,
#          'preserving': 4,
#          'privacy': 9,
#          'k': 7,
#          'anonymisation': 1,
#          'algorithm': 16,
#          'toward': 5,
#          'flexible': 2,
#          'metadata': 1,
#          'indexing': 1,
#          'real': 5,
#          'time': 16,
#          'reference': 2,
#          'introducing': 1,
#          'model': 25,
#          'perform': 1,
#          'technology': 9,
#          'fuzzy': 5,
#          'handling': 6,
#          'apache': 4,
#          'spark': 5,
#          'palopro': 1,
#          'knowledge': 6,
#          'extraction': 5,
#          'news': 1,
#          'ieee': 2,
#          'transaction': 2,
#          'vol': 2,
#          'petuum': 1,
#          'new': 13,
#          'secure': 2,
#          'multi': 8,
#          'owner': 1,
#          'scheme': 3,
#          'monitoring': 5,
#          'camera': 1,
#          'surveillance': 1,
#          'video': 1,
#          'corporate': 1,
#          'governance': 5,
#          'fraud': 2,
#          'annual': 1,
#          'report': 3,
#          'ethical': 1,
#          'concern': 3,
#          'classification': 8,
#          'comparison': 2,
#          'nosql': 2,
#          'dip': 1,
#          'svm': 1,
#          'kernel': 5,
#          'vector': 2,
#          'algorithmseer': 1,
#          'extracting': 3,
#          'searching': 1,
#          'scholarly': 3,
#          'evolving': 3,
#          'role': 5,
#          'fpga': 1,
#          'large': 6,
#          'spectral': 1,
#          'managing': 2,
#          'operation': 1,
#          'fast': 3,
#          'semantic': 4,
#          'composition': 1,
#          'database': 11,
#          'enhanced': 4,
#          'visualization': 6,
#          'method': 8,
#          'aid': 1,
#          'trajectory': 3,
#          'pattern': 2,
#          'recognition': 1,
#          'longitudinal': 1,
#          'resting': 1,
#          'state': 3,
#          'fmri': 1,
#          'functional': 1,
#          'connectivity': 1,
#          'preprocessing': 1,
#          'pipeline': 4,
#          'topological': 1,
#          'extended': 3,
#          'spatio': 2,
#          'temporal': 2,
#          'granger': 1,
#          'causality': 1,
#          'air': 1,
#          'estimation': 5,
#          'heterogeneous': 5,
#          'urban': 3,
#          'availability': 1,
#          'assurance': 1,
#          'comprehensive': 2,
#          'frontier': 3,
#          'gsio': 1,
#          'programmatic': 1,
#          'interface': 1,
#          'delivering': 1,
#          'view': 2,
#          'cube': 1,
#          'interoperability': 1,
#          'stewardship': 1,
#          'sentinel': 2,
#          'landsat': 1,
#          'imagery': 1,
#          'global': 4,
#          'settlement': 1,
#          'mapping': 2,
#          'space': 2,
#          'first': 2,
#          'experience': 1,
#          'timescan': 1,
#          'chain': 3,
#          'semantics': 4,
#          'ontology': 2,
#          'graph': 6,
#          'facilitates': 1,
#          'visual': 3,
#          'open': 2,
#          'public': 7,
#          'transport': 1,
#          'performance': 5,
#          'greater': 1,
#          'sydney': 1,
#          'way': 1,
#          'utilization': 3,
#          'core': 2,
#          'processor': 4,
#          'many': 1,
#          'co': 1,
#          'supercomputer': 1,
#          'beacon': 1,
#          'geocomputation': 1,
#          'geo': 2,
#          'simulation': 3,
#          'generalized': 5,
#          'supervised': 2,
#          'produce': 1,
#          'provincial': 1,
#          'wetland': 1,
#          'inventory': 1,
#          'map': 4,
#          'google': 1,
#          'engine': 1,
#          'spatial': 8,
#          'geosocial': 1,
#          'medium': 8,
#          'crowdsourced': 1,
#          'innovative': 1,
#          'achieving': 1,
#          'belt': 2,
#          'road': 1,
#          'understanding': 8,
#          'climate': 2,
#          'change': 3,
#          'evaluating': 5,
#          'partnership': 1,
#          'increasing': 1,
#          'use': 7,
#          'australian': 1,
#          'impact': 6,
#          'wechat': 1,
#          'blood': 3,
#          'donation': 3,
#          'behavior': 3,
#          'study': 9,
#          'sentiment': 3,
#          'educational': 1,
#          'simd': 1,
#          'mcmc': 1,
#          'sampling': 4,
#          'bayesian': 5,
#          'improving': 2,
#          'shuffle': 1,
#          'phase': 6,
#          'hadoop': 3,
#          'reduce': 2,
#          'small': 4,
#          'bigger': 2,
#          'biggest': 1,
#          'repository': 2,
#          'balloon': 1,
#          'unprecedented': 1,
#          'level': 1,
#          'coping': 1,
#          'transforming': 5,
#          'insight': 5,
#          'nearest': 6,
#          'neighbor': 4,
#          'obtain': 1,
#          'meet': 1,
#          'formal': 1,
#          'practical': 2,
#          'novel': 3,
#          'paradigm': 2,
#          'forecasting': 1,
#          'quantile': 1,
#          'regression': 3,
#          'divide': 2,
#          'conquer': 1,
#          'strategy': 3,
#          'organisation': 1,
#          'leverage': 1,
#          'maturity': 1,
#          'double': 1,
#          'log': 1,
#          'skew': 1,
#          'symmetric': 1,
#          'error': 4,
#          'process': 9,
#          'attribute': 1,
#          'designing': 1,
#          'operating': 1,
#          'mine': 1,
#          'always': 1,
#          'yield': 1,
#          'benefit': 2,
#          'result': 1,
#          'output': 1,
#          'discretization': 1,
#          'taxonomy': 1,
#          'geographical': 1,
#          'condition': 2,
#          'build': 3,
#          'better': 2,
#          'em': 2,
#          'automated': 1,
#          'slicing': 1,
#          'validation': 1,
#          'ai': 4,
#          'integration': 3,
#          'theme': 1,
#          'crime': 1,
#          'detailed': 1,
#          'prominent': 1,
#          'compression': 6,
#          'used': 1,
#          'reducing': 1,
#          'volume': 1,
#          'overview': 3,
#          'electrophysiology': 2,
#          'collection': 1,
#          'recombine': 1,
#          'r': 1,
#          'project': 2,
#          'high': 9,
#          'complexity': 1,
#          'haery': 1,
#          'query': 3,
#          'accumulative': 1,
#          'dimensional': 5,
#          'gamma': 1,
#          'matrix': 3,
#          'summarize': 1,
#          'dense': 1,
#          'sparse': 3,
#          'set': 1,
#          'conference': 1,
#          'bigcomp': 1,
#          'revised': 1,
#          'pyramid': 1,
#          'improves': 1,
#          'mapreduce': 10,
#          'programming': 3,
#          'status': 2,
#          'security': 9,
#          'fusion': 4,
#          'acquired': 1,
#          'multichannel': 1,
#          'wireless': 7,
#          'active': 1,
#          'control': 2,
#          'grid': 3,
#          'industry': 5,
#          'chicken': 1,
#          'swarm': 2,
#          'foraging': 1,
#          'belief': 1,
#          'criminal': 2,
#          'investigation': 2,
#          'assessment': 6,
#          'peer': 1,
#          'produced': 1,
#          'implicit': 1,
#          'wikipedia': 1,
#          'entity': 1,
#          'communication': 5,
#          'applying': 3,
#          'kansei': 1,
#          'hotel': 1,
#          'tool': 3,
#          'experimental': 3,
#          'evaluation': 1,
#          'done': 1,
#          'single': 1,
#          'cell': 4,
#          'transcriptomics': 1,
#          'grand': 1,
#          'academic': 1,
#          'librarian': 1,
#          'competency': 1,
#          'skill': 1,
#          'implementation': 2,
#          'library': 1,
#          'portfolio': 2,
#          'successful': 1,
#          'cyber': 1,
#          'physical': 1,
#          'partner': 1,
#          'allina': 1,
#          'team': 1,
#          'catalyst': 2,
#          'garner': 1,
#          'fundamental': 1,
#          'problem': 4,
#          'memory': 5,
#          'dimensionality': 1,
#          'reduction': 5,
#          'sdn': 1,
#          'michael': 1,
#          'buck': 1,
#          'talk': 1,
#          'living': 1,
#          'dream': 1,
#          'bioinformaticist': 1,
#          'emerging': 1,
#          'alternative': 1,
#          'warehouse': 6,
#          'coal': 1,
#          'fired': 1,
#          'power': 3,
#          'plant': 1,
#          'mongodb': 1,
#          'modular': 1,
#          'building': 7,
#          'rule': 5,
#          'granularity': 1,
#          'phone': 1,
#          'compute': 3,
#          'mobility': 3,
#          'scenario': 1,
#          'future': 5,
#          'city': 4,
#          'advanced': 1,
#          'heavy': 1,
#          'tailed': 1,
#          'china': 5,
#          'deal': 2,
#          'holistic': 1,
#          'consensus': 1,
#          'lime': 1,
#          'effect': 1,
#          'word': 1,
#          'mouth': 1,
#          'csr': 1,
#          'dynamic': 1,
#          'twitter': 3,
#          'barrier': 2,
#          'embedding': 1,
#          'factory': 1,
#          'sap': 1,
#          'consultant': 1,
#          'design': 6,
#          'methodology': 3,
#          'measurement': 5,
#          'incremental': 5,
#          'hyper': 1,
#          'convergent': 1,
#          'regional': 3,
#          'innovation': 2,
#          'responding': 1,
#          'market': 9,
#          'turbulence': 1,
#          'mass': 1,
#          'customization': 1,
#          'path': 1,
#          'success': 1,
#          'banking': 1,
#          'integrated': 1,
#          'advancing': 1,
#          'unlocking': 1,
#          'causal': 1,
#          'relation': 1,
#          'manufacturing': 1,
#          'firm': 2,
#          'straggler': 1,
#          'optimal': 2,
#          'rescheduling': 1,
#          'slow': 1,
#          'running': 1,
#          'lfcso': 1,
#          'lvq': 1,
#          'pso': 1,
#          'subdata': 1,
#          'updating': 1,
#          'correct': 1,
#          'mr': 3,
#          'plot': 2,
#          'distinguishing': 2,
#          'skyline': 2,
#          'computation': 3,
#          'analysing': 2,
#          'repeat': 2,
#          'predicting': 2,
#          'amazon': 2,
#          'product': 2,
#          'comparing': 2,
#          'world': 4,
#          'supply': 2,
#          'finance': 2,
#          'bibliometric': 3,
#          'retail': 2,
#          'apriori': 2,
#          'watchdog': 2,
#          'name': 2,
#          'matching': 2,
#          'risk': 7,
#          'decomposition': 2,
#          'feasibility': 2,
#          'contextual': 2,
#          'federated': 2,
#          'recommender': 2,
#          'step': 2,
#          'nonlinear': 2,
#          'dimension': 6,
#          'direction': 4,
#          'bit': 2,
#          'oriented': 2,
#          'aggregation': 2,
#          'pcce': 2,
#          'personality': 2,
#          'communicative': 2,
#          'community': 5,
#          'v': 2,
#          'non': 6,
#          'simple': 3,
#          'pre': 2,
#          'implication': 2,
#          'era': 6,
#          'semi': 2,
#          'automatic': 2,
#          'fact': 2,
#          'va': 2,
#          'store': 4,
#          'virtual': 2,
#          'approximate': 2,
#          'supporting': 2,
#          'repetitive': 2,
#          'genome': 2,
#          'sequence': 4,
#          'bias': 2,
#          'sample': 2,
#          'broadcasting': 2,
#          'neighbour': 2,
#          'join': 4,
#          'theoretical': 5,
#          'suspicious': 2,
#          'tax': 2,
#          'evasion': 2,
#          'group': 2,
#          'uncertainty': 6,
#          'measure': 2,
#          'conflict': 2,
#          'dempster': 2,
#          'shafer': 2,
#          'linked': 2,
#          'sequential': 2,
#          'localization': 3,
#          'telco': 2,
#          'effective': 2,
#          'clinical': 3,
#          'chunk': 2,
#          'sensing': 9,
#          'source': 2,
#          'recursive': 2,
#          'approximation': 6,
#          'recovery': 4,
#          'dataset': 2,
#          'sensory': 2,
#          'skia': 2,
#          'textual': 2,
#          'fractional': 2,
#          'hot': 2,
#          'deck': 2,
#          'imputation': 2,
#          'variance': 2,
#          'incomplete': 2,
#          'curing': 2,
#          'canonical': 2,
#          'correlation': 2,
#          'multiview': 2,
#          'vecchia': 2,
#          'laplace': 2,
#          'gaussian': 4,
#          'factorization': 2,
#          'series': 4,
#          'blind': 2,
#          'factor': 4,
#          'emulated': 2,
#          'order': 3,
#          'identification': 2,
#          'distrubted': 2,
#          'dws': 2,
#          'technique': 5,
#          'access': 3,
#          'competitive': 4,
#          'advantage': 2,
#          'car': 4,
#          'hailing': 2,
#          'eu': 2,
#          'law': 2,
#          'face': 2,
#          'shake': 2,
#          'enriched': 2,
#          'simplified': 2,
#          'course': 4,
#          'given': 2,
#          'student': 2,
#          'expectation': 2,
#          'frame': 2,
#          'friendly': 2,
#          'commentary': 2,
#          'mo': 4,
#          'orthopaedic': 2,
#          'generalizability': 2,
#          'working': 2,
#          'field': 2,
#          'augmented': 2,
#          'ethnography': 2,
#          'candidate': 4,
#          'interaction': 2,
#          'election': 2,
#          'oracle': 4,
#          'sparc': 4,
#          'accelerates': 2,
#          'recent': 5,
#          'integrate': 2,
#          'hardware': 2,
#          'acceleration': 2,
#          'software': 2,
#          'also': 2,
#          'enable': 2,
#          'ready': 4,
#          'hazy': 2,
#          'easier': 2,
#          'maintain': 2,
#          'racing': 2,
#          'unleash': 2,
#          'full': 2,
#          'latest': 2,
#          'x': 2,
#          'ray': 2,
#          'contrast': 2,
#          'imaging': 2,
#          'safety': 2,
#          'conceptual': 3,
#          'influencing': 2,
#          'transfer': 2,
#          'maximizing': 2,
#          'throughput': 2,
#          'satellite': 2,
#          'yearly': 2,
#          'generation': 4,
#          'aiaa': 2,
#          'formation': 2,
#          'entropy': 2,
#          'alloy': 2,
#          'advance': 5,
#          'informatics': 2,
#          'smarter': 2,
#          'prevention': 2,
#          'sphps': 2,
#          'type': 2,
#          'gene': 2,
#          'expression': 2,
#          'three': 2,
#          'laser': 2,
#          'scanning': 2,
#          'protein': 4,
#          'structure': 4,
#          'metagenomics': 2,
#          'give': 2,
#          'boost': 2,
#          'revamp': 2,
#          'toxicology': 2,
#          'interactive': 3,
#          'growth': 6,
#          'bioinformatics': 3,
#          'workflow': 3,
#          'comparative': 3,
#          'cluster': 4,
#          'reflection': 2,
#          'energy': 12,
#          'electron': 2,
#          'diffraction': 2,
#          'epitaxial': 2,
#          'film': 2,
#          'critical': 6,
#          'government': 2,
#          'charge': 2,
#          'consumption': 2,
#          'electric': 3,
#          'vehicle': 6,
#          'stem': 2,
#          'tissue': 2,
#          'vision': 2,
#          'unique': 2,
#          'incorporating': 2,
#          'smallholder': 2,
#          'palm': 2,
#          'oil': 2,
#          'production': 2,
#          'curation': 2,
#          'coming': 2,
#          'promise': 2,
#          'mitigation': 2,
#          'next': 4,
#          'adaptive': 3,
#          'exception': 2,
#          'parallelized': 2,
#          'gesch': 2,
#          'ftsmodelle': 2,
#          'die': 2,
#          'drei': 2,
#          'seiten': 2,
#          'der': 4,
#          'medaille': 2,
#          'drive': 3,
#          'parking': 2,
#          'policy': 4,
#          'adherence': 2,
#          'meter': 2,
#          'limit': 2,
#          'washington': 2,
#          'c': 3,
#          'technologien': 2,
#          'fahrzeugentwicklung': 2,
#          'literature': 4,
#          'multiperspective': 2,
#          'spectrum': 4,
#          'g': 2,
#          'mechanism': 2,
#          'highlight': 2,
#          'anwendungsf': 2,
#          'lle': 2,
#          'methodisch': 2,
#          'erarbeiten': 2,
#          'screening': 2,
#          'bregman': 2,
#          'divergence': 2,
#          'realm': 2,
#          'possibility': 2,
#          'emergence': 2,
#          'capital': 3,
#          'question': 2,
#          'horizontal': 2,
#          'vertical': 2,
#          'discussion': 2,
#          'battery': 2,
#          'recycling': 2,
#          'edge': 2,
#          'biomarkers': 2,
#          'dynamical': 2,
#          'drug': 2,
#          'sensitivity': 2,
#          'resistance': 3,
#          'individual': 2,
#          'lesson': 2,
#          'assembling': 2,
#          'carbon': 2,
#          'emission': 2,
#          'walkable': 2,
#          'green': 3,
#          'quantification': 2,
#          'variation': 2,
#          'streaming': 2,
#          'concept': 2,
#          'drift': 2,
#          'sears': 2,
#          'away': 2,
#          'job': 2,
#          'outlook': 2,
#          'encouraging': 2,
#          'gm': 2,
#          'plan': 2,
#          'hire': 2,
#          'hp': 2,
#          'employee': 2,
#          'pharmaceutical': 2,
#          'intervention': 2,
#          'covid': 2,
#          'pandemic': 2,
#          'struggle': 2,
#          'birthing': 2,
#          'pain': 2,
#          'researcher': 2,
#          'say': 2,
#          'newton': 2,
#          'merton': 2,
#          'dissemination': 2,
#          'becoming': 2,
#          'savvy': 2,
#          'architecting': 1,
#          'trust': 1,
#          'crowdfunding': 1,
#          'campaign': 1,
#          'marketing': 1,
#          'underpinnings': 1,
#          'migration': 1,
#          'execute': 1,
#          'capturing': 1,
#          'biosurveillance': 1,
#          'natural': 1,
#          'accounting': 1,
#          'futuristic': 3,
#          'fabric': 3,
#          'societal': 3,
#          'diversity': 1,
#          'relationship': 2,
#          'sport': 3,
#          'moving': 3,
#          'consequence': 1,
#          'author': 2,
#          'gong': 1,
#          'comment': 1,
#          'boe': 1,
#          'fusing': 1,
#          'spanish': 1,
#          'official': 1,
#          'gazette': 1,
#          'artificial': 2,
#          'crown': 1,
#          'epidemic': 1,
#          'water': 1,
#          ...})

# %%
word_count = dict()

for tag, counts in count.most_common(10):
    if len(str(tag))>1:
        word_count[tag] = counts
        print('%s : %d' % (tag, counts))
# Out:
# data : 576
# big : 528
# analytics : 89
# based : 46
# analysis : 40
# approach : 39
# issue : 35
# system : 33
# special : 31
# call : 30

# %%
#### 단어개수 차트

# %%
sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(), reverse=True)

plt.bar(range(len(word_count)), sorted_Values, align='center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation=90)
plt.show()

# %%
all_data_concat['doc_count'] = 0
summary_year = all_data_concat.groupby('출판일', as_index=False)['doc_count'].count()
summary_year
# Out:
#      출판일  doc_count
# 0   2004          2
# 1   2011          2
# 2   2012         11
# 3   2013         12
# 4   2014         43
# 5   2015         40
# 6   2016         76
# 7   2017         69
# 8   2018         64
# 9   2019         42
# 10  2020         67
# 11  2021         57
# 12  2022         15

# %%
plt.figure(figsize=(12, 5))
plt.xlabel('year')
plt.ylabel('doc-count')
plt.grid(True)
plt.plot(range(len(summary_year)),summary_year['doc_count'])
plt.xticks(range(len(summary_year)),[text for text in summary_year['출판일']])
plt.show()

# %%
stopwords = set(STOPWORDS)
wc = WordCloud(background_color= 'ivory', stopwords = stopwords, width = 1024, height=700)
cloud = wc.generate_from_frequencies(word_count)
plt.figure(figsize = (8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
cloud.to_file('./data/riss_bigdata_wordCloud.jpg')
